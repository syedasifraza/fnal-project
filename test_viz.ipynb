# %%
import os
import zstandard
from scapy.all import PcapReader
import numpy as np
import concurrent.futures


def decompress_zst_file(input_file, output_file):
    """Decompress a .zst file to its original format."""
    with open(input_file, 'rb') as compressed:
        dctx = zstandard.ZstdDecompressor()
        with open(output_file, 'wb') as decompressed:
            dctx.copy_stream(compressed, decompressed)

def extract_packet_headers(pcap_file):
    """Extract raw packet headers from a pcapng file."""
    headers = []
    with PcapReader(pcap_file) as reader:
        for packet in reader:
            headers.append(bytes(packet))
    return b''.join(headers)  

def segment_into_windows(byte_stream, window_size=1000):
    """Split raw byte stream into fixed-size windows, padded if necessary."""
    num_windows = (len(byte_stream) + window_size - 1) // window_size  # Ceiling division
    padded_stream = byte_stream.ljust(num_windows * window_size, b'\x00')  # Pad with zeros
    return [padded_stream[i:i + window_size] for i in range(0, len(padded_stream), window_size)]

# Step 4: Convert to 32x32 matrices
def windows_to_2d_matrices(windows, matrix_size=(32, 32)):
    """Convert each window of bytes into a 2D matrix."""
    byte_per_matrix = matrix_size[0] * matrix_size[1]
    matrices = []
    for window in windows:
        padded_window = window.ljust(byte_per_matrix, b'\x00')  # Ensure full size
        matrix = np.array(list(padded_window[:byte_per_matrix])).reshape(matrix_size)
        matrices.append(matrix)
    return np.array(matrices)

def process_single_file(zst_file, directory):
    """Process a single .zst file: decompress, extract headers, segment, and save matrices."""
    try:
        input_file = os.path.join(directory, zst_file)
        decompressed_file = input_file.replace('.zst', '')
        output_matrices_file = decompressed_file + "_matrices.npy"

        if os.path.exists(output_matrices_file):
            print(f"Skipping {zst_file}: Matrices already saved at {output_matrices_file}.")
            return
        if os.path.exists(decompressed_file):
            print(f"Skipping decompression for {zst_file}: {decompressed_file} already exists.")

        if not os.path.exists(decompressed_file):
            decompress_zst_file(input_file, decompressed_file)
            print(f"Decompressed {zst_file} to {decompressed_file}.")

        raw_headers = extract_packet_headers(decompressed_file)
        print(f"Extracted{len(raw_headers)} bytes of headers from {decompressed_file}.")

        # Segment into 1000-byte windows
        windows = segment_into_windows(raw_headers, window_size=1000)
        print(f"Segmented into {len(windows)} windows.")

        matrices = windows_to_2d_matrices(windows)
        print(f"Converted into {matrices.shape[0]} matrices of size {matrices.shape[1]}x{matrices.shape[2]}.")

        np.save(output_matrices_file, matrices)
        print(f"Saved matrices to {output_matrices_file}.\n")

    except Exception as e:
        print(f"Error processing {zst_file}: {e}")

def process_all_zst_files_parallel(directory, num_workers=4):
    """Process all .zst files in the directory using multiple workers."""
    zst_files = [f for f in os.listdir(directory) if f.endswith('.zst')]
    print(f"Found {len(zst_files)} .zst files to process in {directory}.")

    with concurrent.futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
        futures = [executor.submit(process_single_file, zst_file, directory) for zst_file in zst_files]
        for future in concurrent.futures.as_completed(futures):
            try:
                future.result()  
            except Exception as e:
                print(f"Error during processing: {e}")

# Run the pipeline
process_all_zst_files_parallel(directory="/tank/swlarsen/2024_10_18/fcc-ht2/run1", num_workers=32)
# Out:
# Found 970 .zst files to process in /tank/swlarsen/2024_10_18/fcc-ht2/run1.
# Decompressed hightouch_00000008_1729174946641636339_fnalfcc-ht2_01_00000.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729174946641636339_fnalfcc-ht2_01_00000.pcapng.
# Extracted 4084 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729174946641636339_fnalfcc-ht2_01_00000.pcapng.
# Segmented into 5 windows.
# Converted into 5 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729174946641636339_fnalfcc-ht2_01_00000.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729288619310778631_fnalfcc-ht2_04_00048.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288619310778631_fnalfcc-ht2_04_00048.pcapng.
# Decompressed hightouch_00000008_1729296548320302455_fnalfcc-ht2_05_00148.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296548320302455_fnalfcc-ht2_05_00148.pcapng.
# Decompressed hightouch_00000008_1729289229647903530_fnalfcc-ht2_04_00058.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289229647903530_fnalfcc-ht2_04_00058.pcapng.
# Decompressed hightouch_00000008_1729296915260506362_fnalfcc-ht2_05_00154.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296915260506362_fnalfcc-ht2_05_00154.pcapng.
# Decompressed hightouch_00000008_1729289778323679891_fnalfcc-ht2_04_00067.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289778323679891_fnalfcc-ht2_04_00067.pcapng.
# Decompressed hightouch_00000008_1729289290310244417_fnalfcc-ht2_04_00059.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289290310244417_fnalfcc-ht2_04_00059.pcapng.
# Decompressed hightouch_00000008_1729288070336686654_fnalfcc-ht2_04_00039.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288070336686654_fnalfcc-ht2_04_00039.pcapng.
# Decompressed hightouch_00000008_1729291662307950338_fnalfcc-ht2_03_00098.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291662307950338_fnalfcc-ht2_03_00098.pcapng.
# Decompressed hightouch_00000008_1729296791424571620_fnalfcc-ht2_02_00151.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296791424571620_fnalfcc-ht2_02_00151.pcapng.
# Decompressed hightouch_00000008_1729287887472407639_fnalfcc-ht2_02_00036.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287887472407639_fnalfcc-ht2_02_00036.pcapng.
# Decompressed hightouch_00000008_1729287826300057161_fnalfcc-ht2_04_00035.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287826300057161_fnalfcc-ht2_04_00035.pcapng.
# Decompressed hightouch_00000008_1729291727314072292_fnalfcc-ht2_02_00099.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291727314072292_fnalfcc-ht2_02_00099.pcapng.
# Decompressed hightouch_00000008_1729292268331691640_fnalfcc-ht2_00_00108.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292268331691640_fnalfcc-ht2_00_00108.pcapng.
# Decompressed hightouch_00000008_1729292938312714873_fnalfcc-ht2_00_00119.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292938312714873_fnalfcc-ht2_00_00119.pcapng.
# Decompressed hightouch_00000008_1729291970342648636_fnalfcc-ht2_04_00103.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291970342648636_fnalfcc-ht2_04_00103.pcapng.
# Decompressed hightouch_00000008_1729286296904962421_fnalfcc-ht2_01_00010.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286296904962421_fnalfcc-ht2_01_00010.pcapng.
# Decompressed hightouch_00000008_1729292697569444987_fnalfcc-ht2_01_00115.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292697569444987_fnalfcc-ht2_01_00115.pcapng.
# Decompressed hightouch_00000008_1729292398311239504_fnalfcc-ht2_02_00110.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292398311239504_fnalfcc-ht2_02_00110.pcapng.
# Decompressed hightouch_00000008_1729291540305357794_fnalfcc-ht2_05_00096.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291540305357794_fnalfcc-ht2_05_00096.pcapng.
# Decompressed hightouch_00000008_1729289959301184119_fnalfcc-ht2_03_00070.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289959301184119_fnalfcc-ht2_03_00070.pcapng.
# Decompressed hightouch_00000008_1729289961328273833_fnalfcc-ht2_02_00070.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289961328273833_fnalfcc-ht2_02_00070.pcapng.
# Decompressed hightouch_00000008_1729290144337828635_fnalfcc-ht2_00_00073.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290144337828635_fnalfcc-ht2_00_00073.pcapng.
# Decompressed hightouch_00000008_1729291418306683918_fnalfcc-ht2_00_00094.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291418306683918_fnalfcc-ht2_00_00094.pcapng.
# Decompressed hightouch_00000008_1729295089345111572_fnalfcc-ht2_01_00124.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295089345111572_fnalfcc-ht2_01_00124.pcapng.
# Decompressed hightouch_00000008_1729295818309087087_fnalfcc-ht2_05_00136.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295818309087087_fnalfcc-ht2_05_00136.pcapng.
# Decompressed hightouch_00000008_1729287158298135177_fnalfcc-ht2_00_00024.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287158298135177_fnalfcc-ht2_00_00024.pcapng.
# Decompressed hightouch_00000008_1729290813309272478_fnalfcc-ht2_02_00084.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290813309272478_fnalfcc-ht2_02_00084.pcapng.
# Decompressed hightouch_00000008_1729287218297901399_fnalfcc-ht2_05_00025.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287218297901399_fnalfcc-ht2_05_00025.pcapng.
# Decompressed hightouch_00000008_1729290384303204196_fnalfcc-ht2_03_00077.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290384303204196_fnalfcc-ht2_03_00077.pcapng.
# Decompressed hightouch_00000008_1729287155299134935_fnalfcc-ht2_03_00024.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287155299134935_fnalfcc-ht2_03_00024.pcapng.
# Decompressed hightouch_00000008_1729295879317024231_fnalfcc-ht2_05_00137.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295879317024231_fnalfcc-ht2_05_00137.pcapng.
# Decompressed hightouch_00000008_1729286550296313108_fnalfcc-ht2_04_00014.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286550296313108_fnalfcc-ht2_04_00014.pcapng.
# Extracted 13976932 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289229647903530_fnalfcc-ht2_04_00058.pcapng.
# Segmented into 13977 windows.
# Extracted 13609740 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296915260506362_fnalfcc-ht2_05_00154.pcapng.
# Segmented into 13610 windows.
# Extracted 12961572 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296548320302455_fnalfcc-ht2_05_00148.pcapng.
# Segmented into 12962 windows.
# Extracted 14597888 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289290310244417_fnalfcc-ht2_04_00059.pcapng.
# Segmented into 14598 windows.
# Extracted 14927128 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288619310778631_fnalfcc-ht2_04_00048.pcapng.
# Segmented into 14928 windows.
# Extracted 14739128 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291662307950338_fnalfcc-ht2_03_00098.pcapng.
# Segmented into 14740 windows.
# Extracted 16282168 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288070336686654_fnalfcc-ht2_04_00039.pcapng.
# Extracted 15814152 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289778323679891_fnalfcc-ht2_04_00067.pcapng.
# Segmented into 15815 windows.
# Segmented into 16283 windows.
# Extracted 15656392 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296791424571620_fnalfcc-ht2_02_00151.pcapng.
# Segmented into 15657 windows.
# Extracted 16835884 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287887472407639_fnalfcc-ht2_02_00036.pcapng.
# Segmented into 16836 windows.
# Extracted 16909088 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291727314072292_fnalfcc-ht2_02_00099.pcapng.
# Segmented into 16910 windows.
# Extracted 17896844 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287826300057161_fnalfcc-ht2_04_00035.pcapng.
# Segmented into 17897 windows.
# Extracted 18033844 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292938312714873_fnalfcc-ht2_00_00119.pcapng.
# Segmented into 18034 windows.
# Extracted 19466672 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292268331691640_fnalfcc-ht2_00_00108.pcapng.
# Segmented into 19467 windows.
# Extracted 21208916 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291970342648636_fnalfcc-ht2_04_00103.pcapng.
# Segmented into 21209 windows.
# Extracted 23331012 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292697569444987_fnalfcc-ht2_01_00115.pcapng.
# Segmented into 23332 windows.
# Extracted 23501232 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286296904962421_fnalfcc-ht2_01_00010.pcapng.
# Segmented into 23502 windows.
# Extracted 26910940 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292398311239504_fnalfcc-ht2_02_00110.pcapng.
# Segmented into 26911 windows.
# Extracted 26909500 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291540305357794_fnalfcc-ht2_05_00096.pcapng.
# Segmented into 26910 windows.
# Converted into 12962 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296548320302455_fnalfcc-ht2_05_00148.pcapng_matrices.npy.
#
# Converted into 13610 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296915260506362_fnalfcc-ht2_05_00154.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729288983551218810_fnalfcc-ht2_03_00054.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288983551218810_fnalfcc-ht2_03_00054.pcapng.
# Converted into 13977 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289229647903530_fnalfcc-ht2_04_00058.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729290994304172550_fnalfcc-ht2_05_00087.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290994304172550_fnalfcc-ht2_05_00087.pcapng.
# Decompressed hightouch_00000008_1729289776391510025_fnalfcc-ht2_03_00067.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289776391510025_fnalfcc-ht2_03_00067.pcapng.
# Converted into 14598 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289290310244417_fnalfcc-ht2_04_00059.pcapng_matrices.npy.
#
# Extracted 34283792 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289959301184119_fnalfcc-ht2_03_00070.pcapng.
# Segmented into 34284 windows.
# Decompressed hightouch_00000008_1729292459311358375_fnalfcc-ht2_02_00111.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292459311358375_fnalfcc-ht2_02_00111.pcapng.
# Converted into 14928 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288619310778631_fnalfcc-ht2_04_00048.pcapng_matrices.npy.
#
# Converted into 14740 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291662307950338_fnalfcc-ht2_03_00098.pcapng_matrices.npy.
#
# Converted into 16910 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291727314072292_fnalfcc-ht2_02_00099.pcapng_matrices.npy.
#
# Extracted 36357928 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289961328273833_fnalfcc-ht2_02_00070.pcapng.
# Segmented into 36358 windows.
# Decompressed hightouch_00000008_1729295692310242015_fnalfcc-ht2_04_00133.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295692310242015_fnalfcc-ht2_04_00133.pcapng.
# Decompressed hightouch_00000008_1729287582384812953_fnalfcc-ht2_04_00031.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287582384812953_fnalfcc-ht2_04_00031.pcapng.
# Converted into 15657 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296791424571620_fnalfcc-ht2_02_00151.pcapng_matrices.npy.
#
# Converted into 15815 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289778323679891_fnalfcc-ht2_04_00067.pcapng_matrices.npy.
#
# Converted into 16283 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288070336686654_fnalfcc-ht2_04_00039.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729287583302285681_fnalfcc-ht2_02_00031.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287583302285681_fnalfcc-ht2_02_00031.pcapng.
# Decompressed hightouch_00000008_1729291052306137167_fnalfcc-ht2_03_00088.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291052306137167_fnalfcc-ht2_03_00088.pcapng.
# Converted into 16836 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287887472407639_fnalfcc-ht2_02_00036.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729297156653304900_fnalfcc-ht2_03_00158.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297156653304900_fnalfcc-ht2_03_00158.pcapng.
# Converted into 17897 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287826300057161_fnalfcc-ht2_04_00035.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729175671552675904_fnalfcc-ht2_01_00007.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729175671552675904_fnalfcc-ht2_01_00007.pcapng.
# Extracted 396 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729175671552675904_fnalfcc-ht2_01_00007.pcapng.
# Segmented into 1 windows.
# Converted into 1 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729175671552675904_fnalfcc-ht2_01_00007.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729287644299926314_fnalfcc-ht2_00_00032.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287644299926314_fnalfcc-ht2_00_00032.pcapng.
# Decompressed hightouch_00000008_1729286548299048266_fnalfcc-ht2_03_00014.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286548299048266_fnalfcc-ht2_03_00014.pcapng.
# Converted into 18034 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292938312714873_fnalfcc-ht2_00_00119.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729286671297007198_fnalfcc-ht2_04_00016.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286671297007198_fnalfcc-ht2_04_00016.pcapng.
# Decompressed hightouch_00000008_1729290141301634322_fnalfcc-ht2_03_00073.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290141301634322_fnalfcc-ht2_03_00073.pcapng.
# Converted into 19467 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292268331691640_fnalfcc-ht2_00_00108.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729292455490633863_fnalfcc-ht2_05_00111.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292455490633863_fnalfcc-ht2_05_00111.pcapng.
# Extracted 15235708 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288983551218810_fnalfcc-ht2_03_00054.pcapng.
# Segmented into 15236 windows.
# Extracted 15736544 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289776391510025_fnalfcc-ht2_03_00067.pcapng.
# Segmented into 15737 windows.
# Converted into 21209 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291970342648636_fnalfcc-ht2_04_00103.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729291910303546765_fnalfcc-ht2_04_00102.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291910303546765_fnalfcc-ht2_04_00102.pcapng.
# Extracted 16609080 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292459311358375_fnalfcc-ht2_02_00111.pcapng.
# Segmented into 16610 windows.
# Converted into 23332 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292697569444987_fnalfcc-ht2_01_00115.pcapng_matrices.npy.
#
# Extracted 15471944 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297156653304900_fnalfcc-ht2_03_00158.pcapng.
# Segmented into 15472 windows.
# Converted into 23502 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286296904962421_fnalfcc-ht2_01_00010.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729296061316578539_fnalfcc-ht2_02_00139.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296061316578539_fnalfcc-ht2_02_00139.pcapng.
# Decompressed hightouch_00000008_1729297215322819495_fnalfcc-ht2_04_00158.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297215322819495_fnalfcc-ht2_04_00158.pcapng.
# Extracted 17473468 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292455490633863_fnalfcc-ht2_05_00111.pcapng.
# Segmented into 17474 windows.
# Converted into 26911 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292398311239504_fnalfcc-ht2_02_00110.pcapng_matrices.npy.
#
# Converted into 26910 matrices of size 32x32.
# Extracted 65286972 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290144337828635_fnalfcc-ht2_00_00073.pcapng.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291540305357794_fnalfcc-ht2_05_00096.pcapng_matrices.npy.
#
# Segmented into 65287 windows.
# Decompressed hightouch_00000008_1729289046336502521_fnalfcc-ht2_02_00055.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289046336502521_fnalfcc-ht2_02_00055.pcapng.
# Decompressed hightouch_00000008_1729296304314702627_fnalfcc-ht2_00_00144.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296304314702627_fnalfcc-ht2_00_00144.pcapng.
# Extracted 67013672 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291418306683918_fnalfcc-ht2_00_00094.pcapng.
# Segmented into 67014 windows.
# Extracted 68850328 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295089345111572_fnalfcc-ht2_01_00124.pcapng.
# Segmented into 68851 windows.
# Converted into 15236 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288983551218810_fnalfcc-ht2_03_00054.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729296912386814069_fnalfcc-ht2_03_00154.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296912386814069_fnalfcc-ht2_03_00154.pcapng.
# Converted into 15737 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289776391510025_fnalfcc-ht2_03_00067.pcapng_matrices.npy.
#
# Extracted 71192436 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290813309272478_fnalfcc-ht2_02_00084.pcapng.
# Segmented into 71193 windows.
# Extracted 15354636 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297215322819495_fnalfcc-ht2_04_00158.pcapng.
# Segmented into 15355 windows.
# Decompressed hightouch_00000008_1729295753311876985_fnalfcc-ht2_04_00134.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295753311876985_fnalfcc-ht2_04_00134.pcapng.
# Converted into 16610 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292459311358375_fnalfcc-ht2_02_00111.pcapng_matrices.npy.
#
# Converted into 15472 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297156653304900_fnalfcc-ht2_03_00158.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729175301052713268_fnalfcc-ht2_03_00004.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729175301052713268_fnalfcc-ht2_03_00004.pcapng.
# Decompressed hightouch_00000008_1729295636308743281_fnalfcc-ht2_03_00133.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295636308743281_fnalfcc-ht2_03_00133.pcapng.
# Extracted 26607308 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291910303546765_fnalfcc-ht2_04_00102.pcapng.
# Segmented into 26608 windows.
# Extracted 899300 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729175301052713268_fnalfcc-ht2_03_00004.pcapng.
# Segmented into 900 windows.
# Extracted 14592456 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289046336502521_fnalfcc-ht2_02_00055.pcapng.
# Segmented into 14593 windows.
# Extracted 81579644 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287158298135177_fnalfcc-ht2_00_00024.pcapng.
# Converted into 900 matrices of size 32x32.
# Segmented into 81580 windows.Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729175301052713268_fnalfcc-ht2_03_00004.pcapng_matrices.npy.
#
#
# Extracted 82509568 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295818309087087_fnalfcc-ht2_05_00136.pcapng.
# Segmented into 82510 windows.
# Decompressed hightouch_00000008_1729296122310286813_fnalfcc-ht2_05_00141.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296122310286813_fnalfcc-ht2_05_00141.pcapng.
# Converted into 34284 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289959301184119_fnalfcc-ht2_03_00070.pcapng_matrices.npy.
#
# Extracted 13667724 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296912386814069_fnalfcc-ht2_03_00154.pcapng.
# Segmented into 13668 windows.
# Extracted 85545004 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290384303204196_fnalfcc-ht2_03_00077.pcapng.
# Segmented into 85546 windows.
# Decompressed hightouch_00000008_1729286793295451242_fnalfcc-ht2_05_00018.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286793295451242_fnalfcc-ht2_05_00018.pcapng.
# Extracted 85148684 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287218297901399_fnalfcc-ht2_05_00025.pcapng.
# Segmented into 85149 windows.
# Extracted 85489064 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287155299134935_fnalfcc-ht2_03_00024.pcapng.
# Segmented into 85490 windows.
# Converted into 17474 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292455490633863_fnalfcc-ht2_05_00111.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729297218923573006_fnalfcc-ht2_00_00159.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297218923573006_fnalfcc-ht2_00_00159.pcapng.
# Converted into 36358 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289961328273833_fnalfcc-ht2_02_00070.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729295696309168828_fnalfcc-ht2_03_00134.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295696309168828_fnalfcc-ht2_03_00134.pcapng.
# Converted into 15355 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297215322819495_fnalfcc-ht2_04_00158.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729289289320924145_fnalfcc-ht2_05_00059.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289289320924145_fnalfcc-ht2_05_00059.pcapng.
# Extracted 97339672 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295879317024231_fnalfcc-ht2_05_00137.pcapng.
# Segmented into 97340 windows.
# Extracted 66468496 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290994304172550_fnalfcc-ht2_05_00087.pcapng.
# Segmented into 66469 windows.
# Converted into 14593 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289046336502521_fnalfcc-ht2_02_00055.pcapng_matrices.npy.
#
# Extracted 99475104 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286550296313108_fnalfcc-ht2_04_00014.pcapng.
# Segmented into 99476 windows.
# Converted into 13668 matrices of size 32x32.
# Decompressed hightouch_00000008_1729287520301216488_fnalfcc-ht2_03_00030.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287520301216488_fnalfcc-ht2_03_00030.pcapng.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296912386814069_fnalfcc-ht2_03_00154.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729296364311366007_fnalfcc-ht2_03_00145.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296364311366007_fnalfcc-ht2_03_00145.pcapng.
# Extracted 15345488 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297218923573006_fnalfcc-ht2_00_00159.pcapng.
# Segmented into 15346 windows.
# Extracted 64504040 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291052306137167_fnalfcc-ht2_03_00088.pcapng.
# Segmented into 64505 windows.
# Extracted 14251160 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289289320924145_fnalfcc-ht2_05_00059.pcapng.
# Segmented into 14252 windows.
# Extracted 64390944 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290141301634322_fnalfcc-ht2_03_00073.pcapng.
# Segmented into 64391 windows.
# Converted into 26608 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291910303546765_fnalfcc-ht2_04_00102.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729288009314571423_fnalfcc-ht2_02_00038.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288009314571423_fnalfcc-ht2_02_00038.pcapng.
# Extracted 54765692 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296304314702627_fnalfcc-ht2_00_00144.pcapng.
# Segmented into 54766 windows.
# Converted into 15346 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297218923573006_fnalfcc-ht2_00_00159.pcapng_matrices.npy.
#
# Extracted 87673228 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295692310242015_fnalfcc-ht2_04_00133.pcapng.
# Segmented into 87674 windows.
# Decompressed hightouch_00000008_1729290809413241077_fnalfcc-ht2_03_00084.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290809413241077_fnalfcc-ht2_03_00084.pcapng.
# Converted into 14252 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289289320924145_fnalfcc-ht2_05_00059.pcapng_matrices.npy.
#
# Extracted 86670720 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286671297007198_fnalfcc-ht2_04_00016.pcapng.
# Segmented into 86671 windows.
# Extracted 88224532 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287644299926314_fnalfcc-ht2_00_00032.pcapng.
# Segmented into 88225 windows.
# Decompressed hightouch_00000008_1729295940362173657_fnalfcc-ht2_05_00138.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295940362173657_fnalfcc-ht2_05_00138.pcapng.
# Extracted 93377000 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287582384812953_fnalfcc-ht2_04_00031.pcapng.
# Segmented into 93377 windows.
# Extracted 15047920 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288009314571423_fnalfcc-ht2_02_00038.pcapng.
# Segmented into 15048 windows.
# Extracted 93740024 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287583302285681_fnalfcc-ht2_02_00031.pcapng.
# Segmented into 93741 windows.
# Extracted 30851012 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296364311366007_fnalfcc-ht2_03_00145.pcapng.
# Segmented into 30852 windows.
# Extracted 82251168 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296061316578539_fnalfcc-ht2_02_00139.pcapng.
# Segmented into 82252 windows.
# Extracted 99404676 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286548299048266_fnalfcc-ht2_03_00014.pcapng.
# Segmented into 99405 windows.
# Converted into 15048 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288009314571423_fnalfcc-ht2_02_00038.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729290749303932208_fnalfcc-ht2_03_00083.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290749303932208_fnalfcc-ht2_03_00083.pcapng.
# Converted into 65287 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290144337828635_fnalfcc-ht2_00_00073.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729296669439169033_fnalfcc-ht2_00_00150.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296669439169033_fnalfcc-ht2_00_00150.pcapng.
# Converted into 67014 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291418306683918_fnalfcc-ht2_00_00094.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729290507302972591_fnalfcc-ht2_05_00079.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290507302972591_fnalfcc-ht2_05_00079.pcapng.
# Converted into 68851 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295089345111572_fnalfcc-ht2_01_00124.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729296791424569672_fnalfcc-ht2_01_00152.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296791424569672_fnalfcc-ht2_01_00152.pcapng.
# Extracted 82050540 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295636308743281_fnalfcc-ht2_03_00133.pcapng.
# Segmented into 82051 windows.
# Converted into 71193 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290813309272478_fnalfcc-ht2_02_00084.pcapng_matrices.npy.
#
# Converted into 30852 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296364311366007_fnalfcc-ht2_03_00145.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729295392311825653_fnalfcc-ht2_03_00129.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295392311825653_fnalfcc-ht2_03_00129.pcapng.
# Decompressed hightouch_00000008_1729286428295829637_fnalfcc-ht2_01_00012.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286428295829637_fnalfcc-ht2_01_00012.pcapng.
# Extracted 16609664 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296669439169033_fnalfcc-ht2_00_00150.pcapng.
# Segmented into 16610 windows.
# Extracted 15645528 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296791424569672_fnalfcc-ht2_01_00152.pcapng.
# Segmented into 15646 windows.
# Extracted 102238536 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295753311876985_fnalfcc-ht2_04_00134.pcapng.
# Segmented into 102239 windows.
# Extracted 86730464 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295696309168828_fnalfcc-ht2_03_00134.pcapng.
# Segmented into 86731 windows.
# Extracted 95726412 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296122310286813_fnalfcc-ht2_05_00141.pcapng.
# Segmented into 95727 windows.
# Extracted 92623412 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286793295451242_fnalfcc-ht2_05_00018.pcapng.
# Segmented into 92624 windows.
# Converted into 66469 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290994304172550_fnalfcc-ht2_05_00087.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729297035476639964_fnalfcc-ht2_02_00155.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297035476639964_fnalfcc-ht2_02_00155.pcapng.
# Converted into 81580 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287158298135177_fnalfcc-ht2_00_00024.pcapng_matrices.npy.
#
# Converted into 16610 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296669439169033_fnalfcc-ht2_00_00150.pcapng_matrices.npy.
#
# Converted into 64505 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291052306137167_fnalfcc-ht2_03_00088.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729297032819148036_fnalfcc-ht2_04_00155.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297032819148036_fnalfcc-ht2_04_00155.pcapng.
# Decompressed hightouch_00000008_1729289898486969898_fnalfcc-ht2_05_00069.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289898486969898_fnalfcc-ht2_05_00069.pcapng.
# Decompressed hightouch_00000008_1729296182310602379_fnalfcc-ht2_03_00142.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296182310602379_fnalfcc-ht2_03_00142.pcapng.
# Converted into 82510 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295818309087087_fnalfcc-ht2_05_00136.pcapng_matrices.npy.
#
# Converted into 15646 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296791424569672_fnalfcc-ht2_01_00152.pcapng_matrices.npy.
#
# Converted into 54766 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296304314702627_fnalfcc-ht2_00_00144.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729290932305901831_fnalfcc-ht2_01_00086.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290932305901831_fnalfcc-ht2_01_00086.pcapng.
# Decompressed hightouch_00000008_1729296182321271843_fnalfcc-ht2_01_00142.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296182321271843_fnalfcc-ht2_01_00142.pcapng.
# Decompressed hightouch_00000008_1729287702300454701_fnalfcc-ht2_03_00033.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287702300454701_fnalfcc-ht2_03_00033.pcapng.
# Converted into 64391 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290141301634322_fnalfcc-ht2_03_00073.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729288131335879949_fnalfcc-ht2_02_00040.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288131335879949_fnalfcc-ht2_02_00040.pcapng.
# Converted into 85490 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287155299134935_fnalfcc-ht2_03_00024.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729291788306303747_fnalfcc-ht2_04_00100.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291788306303747_fnalfcc-ht2_04_00100.pcapng.
# Converted into 85546 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290384303204196_fnalfcc-ht2_03_00077.pcapng_matrices.npy.
#
# Converted into 85149 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287218297901399_fnalfcc-ht2_05_00025.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729288863325027982_fnalfcc-ht2_04_00052.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288863325027982_fnalfcc-ht2_04_00052.pcapng.
# Extracted 71036748 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290809413241077_fnalfcc-ht2_03_00084.pcapng.
# Segmented into 71037 windows.
# Decompressed hightouch_00000008_1729292211316405025_fnalfcc-ht2_03_00107.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292211316405025_fnalfcc-ht2_03_00107.pcapng.
# Extracted 14437152 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297035476639964_fnalfcc-ht2_02_00155.pcapng.
# Segmented into 14438 windows.
# Extracted 14191632 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297032819148036_fnalfcc-ht2_04_00155.pcapng.
# Segmented into 14192 windows.
# Extracted 98517292 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287520301216488_fnalfcc-ht2_03_00030.pcapng.
# Segmented into 98518 windows.
# Extracted 16261344 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289898486969898_fnalfcc-ht2_05_00069.pcapng.
# Segmented into 16262 windows.
# Extracted 40057844 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286428295829637_fnalfcc-ht2_01_00012.pcapng.
# Segmented into 40058 windows.
# Extracted 16241344 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288131335879949_fnalfcc-ht2_02_00040.pcapng.
# Segmented into 16242 windows.
# Extracted 11817356 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292211316405025_fnalfcc-ht2_03_00107.pcapng.
# Segmented into 11818 windows.
# Extracted 16946624 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288863325027982_fnalfcc-ht2_04_00052.pcapng.
# Segmented into 16947 windows.
# Converted into 14438 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297035476639964_fnalfcc-ht2_02_00155.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729296852394208313_fnalfcc-ht2_02_00152.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296852394208313_fnalfcc-ht2_02_00152.pcapng.
# Converted into 11818 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292211316405025_fnalfcc-ht2_03_00107.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729292577321139452_fnalfcc-ht2_05_00113.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292577321139452_fnalfcc-ht2_05_00113.pcapng.
# Converted into 14192 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297032819148036_fnalfcc-ht2_04_00155.pcapng_matrices.npy.
#
# Extracted 23124424 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291788306303747_fnalfcc-ht2_04_00100.pcapng.
# Segmented into 23125 windows.
# Decompressed hightouch_00000008_1729296910417157676_fnalfcc-ht2_04_00153.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296910417157676_fnalfcc-ht2_04_00153.pcapng.
# Converted into 97340 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295879317024231_fnalfcc-ht2_05_00137.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729295939311321308_fnalfcc-ht2_03_00138.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295939311321308_fnalfcc-ht2_03_00138.pcapng.
# Converted into 16262 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289898486969898_fnalfcc-ht2_05_00069.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729290202301754361_fnalfcc-ht2_03_00074.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290202301754361_fnalfcc-ht2_03_00074.pcapng.
# Extracted 93311472 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295940362173657_fnalfcc-ht2_05_00138.pcapng.
# Segmented into 93312 windows.
# Extracted 66519788 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290507302972591_fnalfcc-ht2_05_00079.pcapng.
# Segmented into 66520 windows.
# Converted into 16242 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288131335879949_fnalfcc-ht2_02_00040.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729293123309980846_fnalfcc-ht2_03_00122.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729293123309980846_fnalfcc-ht2_03_00122.pcapng.
# Converted into 99476 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286550296313108_fnalfcc-ht2_04_00014.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729296425317449715_fnalfcc-ht2_02_00145.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296425317449715_fnalfcc-ht2_02_00145.pcapng.
# Extracted 1469004 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729293123309980846_fnalfcc-ht2_03_00122.pcapng.
# Segmented into 1470 windows.
# Extracted 75850740 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290749303932208_fnalfcc-ht2_03_00083.pcapng.
# Segmented into 75851 windows.
# Converted into 1470 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729293123309980846_fnalfcc-ht2_03_00122.pcapng_matrices.npy.
#
# Converted into 16947 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288863325027982_fnalfcc-ht2_04_00052.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729291544365722011_fnalfcc-ht2_02_00096.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291544365722011_fnalfcc-ht2_02_00096.pcapng.
# Decompressed hightouch_00000008_1729296057372881707_fnalfcc-ht2_04_00139.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296057372881707_fnalfcc-ht2_04_00139.pcapng.
# Extracted 13597216 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296910417157676_fnalfcc-ht2_04_00153.pcapng.
# Segmented into 13598 windows.
# Extracted 15437208 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296852394208313_fnalfcc-ht2_02_00152.pcapng.
# Segmented into 15438 windows.
# Extracted 17906244 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292577321139452_fnalfcc-ht2_05_00113.pcapng.
# Segmented into 17907 windows.
# Converted into 87674 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295692310242015_fnalfcc-ht2_04_00133.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729292881513310417_fnalfcc-ht2_05_00118.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292881513310417_fnalfcc-ht2_05_00118.pcapng.
# Converted into 86671 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286671297007198_fnalfcc-ht2_04_00016.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729289412340099347_fnalfcc-ht2_00_00061.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289412340099347_fnalfcc-ht2_00_00061.pcapng.
# Converted into 88225 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287644299926314_fnalfcc-ht2_00_00032.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729291660310019259_fnalfcc-ht2_01_00098.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291660310019259_fnalfcc-ht2_01_00098.pcapng.
# Converted into 82252 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296061316578539_fnalfcc-ht2_02_00139.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729296483313373399_fnalfcc-ht2_04_00146.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296483313373399_fnalfcc-ht2_04_00146.pcapng.
# Converted into 93377 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287582384812953_fnalfcc-ht2_04_00031.pcapng_matrices.npy.
#
# Converted into 23125 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291788306303747_fnalfcc-ht2_04_00100.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729288678413926591_fnalfcc-ht2_03_00049.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288678413926591_fnalfcc-ht2_03_00049.pcapng.
# Decompressed hightouch_00000008_1729291416310066511_fnalfcc-ht2_01_00094.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291416310066511_fnalfcc-ht2_01_00094.pcapng.
# Converted into 13598 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296910417157676_fnalfcc-ht2_04_00153.pcapng_matrices.npy.
#
# Extracted 60776336 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290932305901831_fnalfcc-ht2_01_00086.pcapng.
# Segmented into 60777 windows.
# Converted into 15438 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296852394208313_fnalfcc-ht2_02_00152.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729296304318663955_fnalfcc-ht2_01_00144.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296304318663955_fnalfcc-ht2_01_00144.pcapng.
# Extracted 23016432 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296425317449715_fnalfcc-ht2_02_00145.pcapng.
# Segmented into 23017 windows.
# Decompressed hightouch_00000008_1729290264302658285_fnalfcc-ht2_05_00075.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290264302658285_fnalfcc-ht2_05_00075.pcapng.
# Converted into 93741 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287583302285681_fnalfcc-ht2_02_00031.pcapng_matrices.npy.
#
# Extracted 14545088 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289412340099347_fnalfcc-ht2_00_00061.pcapng.
# Segmented into 14546 windows.
# Extracted 14831024 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291660310019259_fnalfcc-ht2_01_00098.pcapng.
# ...
# Segmented into 16258 windows.
# Extracted 15668772 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288736484201252_fnalfcc-ht2_01_00050.pcapng.
# Segmented into 15669 windows.
# Extracted 15579108 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296792321410355_fnalfcc-ht2_05_00152.pcapng.
# Segmented into 15580 windows.
# Converted into 43553 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286368243247096_fnalfcc-ht2_01_00011.pcapng_matrices.npy.
#
# Converted into 83706 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286489311223236_fnalfcc-ht2_04_00013.pcapng_matrices.npy.
#
# Extracted 22605532 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292520310717172_fnalfcc-ht2_02_00112.pcapng.
# Segmented into 22606 windows.
# Decompressed hightouch_00000008_1729295150312555080_fnalfcc-ht2_01_00125.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295150312555080_fnalfcc-ht2_01_00125.pcapng.
# Decompressed hightouch_00000008_1729295698312807748_fnalfcc-ht2_00_00134.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295698312807748_fnalfcc-ht2_00_00134.pcapng.
# Converted into 16258 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288131299045857_fnalfcc-ht2_05_00040.pcapng_matrices.npy.
#
# Extracted 27622232 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292393330466108_fnalfcc-ht2_03_00110.pcapng.
# Segmented into 27623 windows.
# Decompressed hightouch_00000008_1729290510306440772_fnalfcc-ht2_02_00079.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290510306440772_fnalfcc-ht2_02_00079.pcapng.
# Converted into 15669 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288736484201252_fnalfcc-ht2_01_00050.pcapng_matrices.npy.
#
# Converted into 15580 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296792321410355_fnalfcc-ht2_05_00152.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729297219793700141_fnalfcc-ht2_05_00159.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297219793700141_fnalfcc-ht2_05_00159.pcapng.
# Extracted 109856624 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296001313396207_fnalfcc-ht2_00_00139.pcapng.
# Segmented into 109857 windows.
# Decompressed hightouch_00000008_1729295331309439559_fnalfcc-ht2_03_00128.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295331309439559_fnalfcc-ht2_03_00128.pcapng.
# Converted into 65938 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291117308646021_fnalfcc-ht2_02_00089.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729285955206015142_fnalfcc-ht2_04_00008.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729285955206015142_fnalfcc-ht2_04_00008.pcapng.
# Converted into 22606 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292520310717172_fnalfcc-ht2_02_00112.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729295089308266788_fnalfcc-ht2_03_00124.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295089308266788_fnalfcc-ht2_03_00124.pcapng.
# Extracted 65317396 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291296306302366_fnalfcc-ht2_03_00092.pcapng.
# Segmented into 65318 windows.
# Extracted 87581180 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287095298258444_fnalfcc-ht2_03_00023.pcapng.
# Segmented into 87582 windows.
# Extracted 9862320 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729285955206015142_fnalfcc-ht2_04_00008.pcapng.
# Segmented into 9863 windows.
# Converted into 91852 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295454344046782_fnalfcc-ht2_00_00130.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729296485311568194_fnalfcc-ht2_03_00147.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296485311568194_fnalfcc-ht2_03_00147.pcapng.
# Converted into 90602 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295393309090448_fnalfcc-ht2_05_00129.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729291723927483273_fnalfcc-ht2_03_00099.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291723927483273_fnalfcc-ht2_03_00099.pcapng.
# Converted into 92009 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295149308362579_fnalfcc-ht2_03_00125.pcapng_matrices.npy.
#
# Converted into 27623 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292393330466108_fnalfcc-ht2_03_00110.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729292755395673161_fnalfcc-ht2_00_00116.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292755395673161_fnalfcc-ht2_00_00116.pcapng.
# Decompressed hightouch_00000008_1729289163554488100_fnalfcc-ht2_01_00057.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289163554488100_fnalfcc-ht2_01_00057.pcapng.
# Extracted 15466912 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297219793700141_fnalfcc-ht2_05_00159.pcapng.
# Segmented into 15467 windows.
# Converted into 9863 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729285955206015142_fnalfcc-ht2_04_00008.pcapng_matrices.npy.
#
# Converted into 64824 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286975321235214_fnalfcc-ht2_00_00021.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729289594456700840_fnalfcc-ht2_05_00064.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289594456700840_fnalfcc-ht2_05_00064.pcapng.
# Decompressed hightouch_00000008_1729289412340107509_fnalfcc-ht2_04_00061.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289412340107509_fnalfcc-ht2_04_00061.pcapng.
# Extracted 79222992 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290749310975702_fnalfcc-ht2_01_00083.pcapng.
# Segmented into 79223 windows.
# Converted into 89543 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295576452865960_fnalfcc-ht2_02_00131.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729292942307099793_fnalfcc-ht2_05_00119.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292942307099793_fnalfcc-ht2_05_00119.pcapng.
# Converted into 15467 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297219793700141_fnalfcc-ht2_05_00159.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729293009347408506_fnalfcc-ht2_02_00120.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729293009347408506_fnalfcc-ht2_02_00120.pcapng.
# Extracted 65475648 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291052307337560_fnalfcc-ht2_01_00088.pcapng.
# Segmented into 65476 windows.
# Extracted 15127160 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296485311568194_fnalfcc-ht2_03_00147.pcapng.
# Segmented into 15128 windows.
# Converted into 90332 matrices of size 32x32.
# Extracted 109790876 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295996313094642_fnalfcc-ht2_04_00138.pcapng.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287340299444145_fnalfcc-ht2_00_00027.pcapng_matrices.npy.
#
# Segmented into 109791 windows.
# Decompressed hightouch_00000008_1729297218923575050_fnalfcc-ht2_01_00159.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297218923575050_fnalfcc-ht2_01_00159.pcapng.
# Extracted 16162160 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291723927483273_fnalfcc-ht2_03_00099.pcapng.
# Segmented into 16163 windows.
# Extracted 74190724 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287036306917127_fnalfcc-ht2_00_00022.pcapng.
# Segmented into 74191 windows.
# Extracted 108517216 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296000309562457_fnalfcc-ht2_03_00139.pcapng.
# Extracted 13754756 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289594456700840_fnalfcc-ht2_05_00064.pcapng.
# Segmented into 13755 windows.
# Segmented into 108518 windows.
# Extracted 17301300 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289163554488100_fnalfcc-ht2_01_00057.pcapng.
# Segmented into 17302 windows.
# Extracted 14473908 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289412340107509_fnalfcc-ht2_04_00061.pcapng.
# Segmented into 14474 windows.
# Converted into 15128 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296485311568194_fnalfcc-ht2_03_00147.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729297341342482841_fnalfcc-ht2_05_00161.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297341342482841_fnalfcc-ht2_05_00161.pcapng.
# Converted into 82515 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287216299148642_fnalfcc-ht2_03_00025.pcapng_matrices.npy.
#
# Extracted 17077816 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292942307099793_fnalfcc-ht2_05_00119.pcapng.
# Segmented into 17078 windows.
# Converted into 16163 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291723927483273_fnalfcc-ht2_03_00099.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729287096303107632_fnalfcc-ht2_01_00023.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287096303107632_fnalfcc-ht2_01_00023.pcapng.
# Extracted 16043092 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729293009347408506_fnalfcc-ht2_02_00120.pcapng.
# Segmented into 16044 windows.
# Extracted 60264512 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290933329763735_fnalfcc-ht2_05_00086.pcapng.
# Segmented into 60265 windows.
# Converted into 13755 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289594456700840_fnalfcc-ht2_05_00064.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729287643312399643_fnalfcc-ht2_04_00032.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287643312399643_fnalfcc-ht2_04_00032.pcapng.
# Extracted 24958760 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292755395673161_fnalfcc-ht2_00_00116.pcapng.
# Segmented into 24959 windows.
# Converted into 17302 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289163554488100_fnalfcc-ht2_01_00057.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729286974347869334_fnalfcc-ht2_04_00021.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729286974347869334_fnalfcc-ht2_04_00021.pcapng.
# Decompressed hightouch_00000008_1729290628303405884_fnalfcc-ht2_03_00081.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729290628303405884_fnalfcc-ht2_03_00081.pcapng.
# Converted into 14474 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729289412340107509_fnalfcc-ht2_04_00061.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729175547276808309_fnalfcc-ht2_03_00005.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729175547276808309_fnalfcc-ht2_03_00005.pcapng.
# Extracted 880064 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729175547276808309_fnalfcc-ht2_03_00005.pcapng.
# Segmented into 881 windows.
# Extracted 15319944 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297218923575050_fnalfcc-ht2_01_00159.pcapng.
# Segmented into 15320 windows.
# Converted into 881 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729175547276808309_fnalfcc-ht2_03_00005.pcapng_matrices.npy.
#
# Converted into 114186 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295515313401517_fnalfcc-ht2_02_00130.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729291235306174413_fnalfcc-ht2_03_00091.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291235306174413_fnalfcc-ht2_03_00091.pcapng.
# Converted into 17078 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292942307099793_fnalfcc-ht2_05_00119.pcapng_matrices.npy.
#
# Converted into 16044 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729293009347408506_fnalfcc-ht2_02_00120.pcapng_matrices.npy.
#
# Converted into 87241 matrices of size 32x32.
# Decompressed hightouch_00000008_1729288741325880421_fnalfcc-ht2_04_00050.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288741325880421_fnalfcc-ht2_04_00050.pcapng.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729287401304384226_fnalfcc-ht2_00_00028.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729288617306225962_fnalfcc-ht2_03_00048.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288617306225962_fnalfcc-ht2_03_00048.pcapng.
# Decompressed hightouch_00000008_1729288009314584988_fnalfcc-ht2_00_00038.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288009314584988_fnalfcc-ht2_00_00038.pcapng.
# Converted into 107982 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296001308791920_fnalfcc-ht2_05_00139.pcapng_matrices.npy.
#
# Extracted 12368412 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297341342482841_fnalfcc-ht2_05_00161.pcapng.
# Segmented into 12369 windows.
# Extracted 72438120 bytes of headers from /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729291361303395147_fnalfcc-ht2_04_00093.pcapng.
# Decompressed hightouch_00000008_1729288739539646115_fnalfcc-ht2_03_00050.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729288739539646115_fnalfcc-ht2_03_00050.pcapng.
# Segmented into 72439 windows.
# Decompressed hightouch_00000008_1729295514309742115_fnalfcc-ht2_03_00131.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729295514309742115_fnalfcc-ht2_03_00131.pcapng.
# Converted into 15320 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729297218923575050_fnalfcc-ht2_01_00159.pcapng_matrices.npy.
#
# Decompressed hightouch_00000008_1729296425314787998_fnalfcc-ht2_00_00146.pcapng.zst to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729296425314787998_fnalfcc-ht2_00_00146.pcapng.
# Converted into 24959 matrices of size 32x32.
# Saved matrices to /tank/swlarsen/2024_10_18/fcc-ht2/run1/hightouch_00000008_1729292755395673161_fnalfcc-ht2_00_00116.pcapng_matrices.npy.
